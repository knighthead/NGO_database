# %%
import codecs
import requests
from bs4 import BeautifulSoup
import random
from collections import OrderedDict
import re
from types import *

headers_of_request = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.87 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Encoding': 'gzip, deflate, sdch',
    'Accept-Language': 'en-US,en;q=0.5',
    'Connection': 'keep-alive',
    'Host': 'www.wango.org'
}

def relevant_links(tag):
    a = False
    if (tag.name==u'a' and tag.has_attr('href')):
        if (tag['href'].find('javascript:loadOrg(')!=-1):
            a = True
    return a

s = requests.Session()
s.headers.update(headers_of_request)

# %% [markdown]
# .. code:: python:
#
#     def relevant_links(tag):
#         a = false
#         if (tag.name==u'a' and tag.has_attr('href')):
#             if (tag['href'].find('javascript:loadOrg(')!=-1):
#                 ngo_id = re.search("javascript:loadOrg((.+?));",tag['href'])
#                 if ngo_id:
#                     a = ngo_id.group(1)[2:-2]
#             else:
#                 a = '-1'
#         else:
#             a = '-1'
#         return int(float(a))

# %%
BaseUrl = 'http://www.wango.org'
SubUrl = '/resources.aspx?section=ngodir'

'''SubSubUrl = '&sub=region&regionID=5&col=cc3300'
'''

payload = OrderedDict([('sub','region'),('regionID', '5'),('col', 'cc3300')])



ngo_initial_response = s.get(url=(BaseUrl + SubUrl),params=payload)
print ngo_initial_response.url
print ngo_initial_response.status_code
print ngo_initial_response.request.body
# Out:
# http://www.wango.org/resources.aspx?section=ngodir&sub=region&regionID=5&col=cc3300
# 200
# None

# %%
request_item = OrderedDict([
    ("Countries", "32,68,76,152,170,218,238,254,328,600,604,740,858,862,0"),
    ("InterestAreas", "Environment"),
    ("currpage", 1)
])
referer = {
    'Referer': ngo_initial_response.url
}



payload2 = OrderedDict([('sub','list'),('regionID', '5'),('col', 'cc3300')])
ngo_filtered_response = s.post(url=(BaseUrl + SubUrl),params=payload2, data=request_item, headers=referer)
print ngo_filtered_response.url
print ngo_filtered_response.status_code
print ngo_filtered_response.request.body
# Out:
# http://www.wango.org/resources.aspx?section=ngodir&sub=list&regionID=5&col=cc3300
# 200
# Countries=32%2C68%2C76%2C152%2C170%2C218%2C238%2C254%2C328%2C600%2C604%2C740%2C858%2C862%2C0&InterestAreas=Environment&currpage=1

# %%
ngo_soup = BeautifulSoup(ngo_filtered_response.content,'lxml')

# %% [markdown]
# print ngo_soup.prettify()

# %%
filtered_content = ngo_soup.find('div',{'class': 'content'})
filtered_pages_content = filtered_content.find('td',{'valign': 'top'}).find('div',{'align': 'left'})
number_of_pages = -1

for link in filtered_pages_content.findAll('a'):
    number_of_pages += 1

# %%
main_content = filtered_content.find('td',{'valign': 'top'})
print main_content.prettify()
# Out:
# <td valign="top">
#  <div align="left">
#   Page:
#   <b>
#    1
#   </b>
#   <a href="javascript:goPage('2',  '', 'zz');void(0);">
#    2
#   </a>
#   <a href="javascript:goPage('2',  '', 'zz');void(0);">
#    &gt;
#   </a>
#   <a href="javascript:goPage('2',  '', 'zz');void(0);">
#    &gt;&gt;
#   </a>
#  </div>
#  <br/>
#  <!-- <tr>
#       <td class="ngodir_td_red"><b>Organization</b></td>
#      <td class="ngodir_td_red"><b>Country</b></td>
#   </tr>-->
#  <img height="5" src="images/0.gif" width="10"/>
#  <br/>
#  <script language="javascript">
#   function loadOrg( id )
# {
# 	if( !document.getElementById  )
# 	{
# 		cpopUp('org_details.aspx?orgID=' + id );
# 	}
# 	else
# 	{
# 		var f = document.getElementById( "loader" );
# 		if( f.innerHTML == "" || !f.contentWindow ) cpopUp('org_details.aspx?orgID=' + id );
# 		else
# 		{
# 			//if already loaded, hide
# 			var t = document.getElementById( "d" + id );
# 			if( t.style.display == "block" ) hideOrgDetails( id );
# 			else
# 			{
# 				document.getElementById( "s" + id ).style.display="none";
# 				document.getElementById( "l" + id ).style.display="block";
# 				f.src = "org_details.aspx?inline=1&orgID=" + id; //load data
# 			}
# 		}
# 	}
# }
#
# function onLoadOrg( id )
# {
# 	document.getElementById( "l" + id ).style.display="none";
# 	document.getElementById( "s" + id ).style.display="none";
# 	var t = document.getElementById( "d" + id );
# 	var f = document.getElementById( "loader" );
# 	t.innerHTML = f.contentWindow.document.getElementById( "content" ).innerHTML;
# 	t.style.display = "block";
# }
# function hideOrgDetails( id )
# {
# 	document.getElementById( "d" + id ).style.display="none";
# 	document.getElementById( "s" + id ).style.display="block";
# }
#  </script>
#  <a href="javascript:loadOrg('824');">
#   <b>
#    Aguia Dourada Organizacao Multicultural Indigena do Nordeste
#   </b>
#  </a>
#  <br/>
#  <div id="l824" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s824">
#   <div class="contentmargin0" style="color:#666666;">
#    Bahia, Brazil
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Brazil</td>-->
#  <div id="d824">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10586209');">
#   <b>
#    AIBEX
#   </b>
#  </a>
#  <br/>
#  <div id="l10586209" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10586209">
#   <div class="contentmargin0" style="color:#666666;">
#    Montevideo, Uruguay
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Uruguay</td>-->
#  <div id="d10586209">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10580947');">
#   <b>
#    Aldeas de Paz
#   </b>
#  </a>
#  <br/>
#  <div id="l10580947" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10580947">
#   <div class="contentmargin0" style="color:#666666;">
#    Santa Elena de Uairen, Venezuela
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Venezuela</td>-->
#  <div id="d10580947">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('17172');">
#   <b>
#    Alter Vida, Center of Studies and Training for Eco-Development
#   </b>
#  </a>
#  <br/>
#  <div id="l17172" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s17172">
#   <div class="contentmargin0" style="color:#666666;">
#    Asuncion, Paraguay
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Paraguay</td>-->
#  <div id="d17172">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10583244');">
#   <b>
#    Amazonas
#   </b>
#  </a>
#  <br/>
#  <div id="l10583244" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10583244">
#   <div class="contentmargin0" style="color:#666666;">
#    Villa Rica, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10583244">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10582006');">
#   <b>
#    Asociacion Para la Proteccion, Reserva y Desarrollo del Q'onec
#   </b>
#  </a>
#  <br/>
#  <div id="l10582006" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10582006">
#   <div class="contentmargin0" style="color:#666666;">
#    Cusco, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10582006">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10593128');">
#   <b>
#    Asociacion Sharing dreams - Peru
#   </b>
#  </a>
#  <br/>
#  <div id="l10593128" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10593128">
#   <div class="contentmargin0" style="color:#666666;">
#    Huancayo, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10593128">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('383');">
#   <b>
#    Asociacion Trabajadores Autonomos siglo XXI
#   </b>
#  </a>
#  <br/>
#  <div id="l383" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s383">
#   <div class="contentmargin0" style="color:#666666;">
#    Salcedo, Ecuador
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Ecuador</td>-->
#  <div id="d383">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10590124');">
#   <b>
#    AssociaÃ§Ã£o Academia Goiana de PsicanÃ¡lise (AGPsicanalise)
#   </b>
#  </a>
#  <br/>
#  <div id="l10590124" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10590124">
#   <div class="contentmargin0" style="color:#666666;">
#    Anapolis, Brazil
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Brazil</td>-->
#  <div id="d10590124">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10582318');">
#   <b>
#    AssociaÃ§Ã£o EcolÃ³gica Amigos de Pindorama
#   </b>
#  </a>
#  <br/>
#  <div id="l10582318" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10582318">
#   <div class="contentmargin0" style="color:#666666;">
#    Criciuma, Brazil
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Brazil</td>-->
#  <div id="d10582318">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10522771');">
#   <b>
#    Bureau Forum NGOs
#   </b>
#  </a>
#  <br/>
#  <div id="l10522771" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10522771">
#   <div class="contentmargin0" style="color:#666666;">
#    Paramaribo, Suriname
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Suriname</td>-->
#  <div id="d10522771">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('126');">
#   <b>
#    Centro Espirita Amor e Sabedoria
#   </b>
#  </a>
#  <br/>
#  <div id="l126" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s126">
#   <div class="contentmargin0" style="color:#666666;">
#    Lauro de Freitas, Brazil
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Brazil</td>-->
#  <div id="d126">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10589454');">
#   <b>
#    Charles Darwin Foundation (CDF)
#   </b>
#  </a>
#  <br/>
#  <div id="l10589454" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10589454">
#   <div class="contentmargin0" style="color:#666666;">
#    Puerto Ayora, Ecuador
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Ecuador</td>-->
#  <div id="d10589454">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10585352');">
#   <b>
#    Cidades Sem Fome (Cities Without Hunger)
#   </b>
#  </a>
#  <br/>
#  <div id="l10585352" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10585352">
#   <div class="contentmargin0" style="color:#666666;">
#    Sao Paulo, Brazil
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Brazil</td>-->
#  <div id="d10585352">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('17187');">
#   <b>
#    CIDSEP-UC
#   </b>
#  </a>
#  <br/>
#  <div id="l17187" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s17187">
#   <div class="contentmargin0" style="color:#666666;">
#    AsunciÃ³n, Paraguay
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Paraguay</td>-->
#  <div id="d17187">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10590777');">
#   <b>
#    Cities Without Hunger  (Cidades sem Fome)
#   </b>
#  </a>
#  <br/>
#  <div id="l10590777" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10590777">
#   <div class="contentmargin0" style="color:#666666;">
#    Sao Paulo, Brazil
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Brazil</td>-->
#  <div id="d10590777">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10574290');">
#   <b>
#    Corporacion Latina de Capacitacion y Desarrollo de Lideres y Emprndedores CORPOLIDER
#   </b>
#  </a>
#  <br/>
#  <div id="l10574290" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10574290">
#   <div class="contentmargin0" style="color:#666666;">
#    Guayaquil, Ecuador
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Ecuador</td>-->
#  <div id="d10574290">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10577611');">
#   <b>
#    Corporacion para el Desarrollo de Proyectos Ambientales Interdisciplinarios Sostenibles - CODEPAIS
#   </b>
#  </a>
#  <br/>
#  <div id="l10577611" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10577611">
#   <div class="contentmargin0" style="color:#666666;">
#    Bogota, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10577611">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10574796');">
#   <b>
#    Corporacion Prosperar de Colombia "CORPROSPERAR"
#   </b>
#  </a>
#  <br/>
#  <div id="l10574796" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10574796">
#   <div class="contentmargin0" style="color:#666666;">
#    Bucaramanga, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10574796">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10591232');">
#   <b>
#    Echelecu
#   </b>
#  </a>
#  <br/>
#  <div id="l10591232" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10591232">
#   <div class="contentmargin0" style="color:#666666;">
#    Lima, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10591232">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10664');">
#   <b>
#    Econatura Andina
#   </b>
#  </a>
#  <br/>
#  <div id="l10664" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10664">
#   <div class="contentmargin0" style="color:#666666;">
#    Puno, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10664">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10576022');">
#   <b>
#    El Capital Humano
#   </b>
#  </a>
#  <br/>
#  <div id="l10576022" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10576022">
#   <div class="contentmargin0" style="color:#666666;">
#    Lima, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10576022">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10574420');">
#   <b>
#    FIDEH-FundaciÃ³n Icono Integral para el Desarrollo Humano
#   </b>
#  </a>
#  <br/>
#  <div id="l10574420" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10574420">
#   <div class="contentmargin0" style="color:#666666;">
#    La Paz, Bolivia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Bolivia</td>-->
#  <div id="d10574420">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10581593');">
#   <b>
#    Fideicomiso Ecuatoriano de CooperaciÃ³n para el Desarrollo
#   </b>
#  </a>
#  <br/>
#  <div id="l10581593" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10581593">
#   <div class="contentmargin0" style="color:#666666;">
#    Quito, Ecuador
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Ecuador</td>-->
#  <div id="d10581593">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10582247');">
#   <b>
#    Funda-CEDITEC Centro de Innovacion Tecnologica y Cooperacion Internacional
#   </b>
#  </a>
#  <br/>
#  <div id="l10582247" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10582247">
#   <div class="contentmargin0" style="color:#666666;">
#    Caracas, Venezuela
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Venezuela</td>-->
#  <div id="d10582247">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10574400');">
#   <b>
#    Fundacin Prosurgir
#   </b>
#  </a>
#  <br/>
#  <div id="l10574400" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10574400">
#   <div class="contentmargin0" style="color:#666666;">
#    Bogata, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10574400">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('993');">
#   <b>
#    Fundacion Administracion para el Desarrollo
#   </b>
#  </a>
#  <br/>
#  <div id="l993" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s993">
#   <div class="contentmargin0" style="color:#666666;">
#    Quito, Ecuador
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Ecuador</td>-->
#  <div id="d993">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10585363');">
#   <b>
#    FUNDACION AGAPE
#   </b>
#  </a>
#  <br/>
#  <div id="l10585363" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10585363">
#   <div class="contentmargin0" style="color:#666666;">
#    Cartagena, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10585363">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10589885');">
#   <b>
#    Fundacion Agape
#   </b>
#  </a>
#  <br/>
#  <div id="l10589885" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10589885">
#   <div class="contentmargin0" style="color:#666666;">
#    Magangue, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10589885">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10579388');">
#   <b>
#    Fundacion Apertura
#   </b>
#  </a>
#  <br/>
#  <div id="l10579388" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10579388">
#   <div class="contentmargin0" style="color:#666666;">
#    Ciudad Autonoma de Buenos Aires, Argentina
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Argentina</td>-->
#  <div id="d10579388">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10576589');">
#   <b>
#    Fundacion Colombiana FUNCASOL USA
#   </b>
#  </a>
#  <br/>
#  <div id="l10576589" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10576589">
#   <div class="contentmargin0" style="color:#666666;">
#    Palmira, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10576589">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10581130');">
#   <b>
#    FundaciÃ³n Herpetario Nacional
#   </b>
#  </a>
#  <br/>
#  <div id="l10581130" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10581130">
#   <div class="contentmargin0" style="color:#666666;">
#    BogotÃ¡ D.C., Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10581130">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10581235');">
#   <b>
#    FundaciÃ³n La NaciÃ³n
#   </b>
#  </a>
#  <br/>
#  <div id="l10581235" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10581235">
#   <div class="contentmargin0" style="color:#666666;">
#    Ciudad AutÃ³noma de Buenos Aires, Argentina
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Argentina</td>-->
#  <div id="d10581235">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10584367');">
#   <b>
#    Fundacion para la Promocion y Desarrollo Integral
#   </b>
#  </a>
#  <br/>
#  <div id="l10584367" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10584367">
#   <div class="contentmargin0" style="color:#666666;">
#    Amalfi, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10584367">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10579375');">
#   <b>
#    FundaciÃn Pro Vulnerables
#   </b>
#  </a>
#  <br/>
#  <div id="l10579375" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10579375">
#   <div class="contentmargin0" style="color:#666666;">
#    Cali, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10579375">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10588285');">
#   <b>
#    FundaciÃ³n Sociales en LÃ­nea
#   </b>
#  </a>
#  <br/>
#  <div id="l10588285" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10588285">
#   <div class="contentmargin0" style="color:#666666;">
#    MedellÃ­n, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10588285">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('114');">
#   <b>
#    Grupo de Evangelizacao Gotas de Esperanca
#   </b>
#  </a>
#  <br/>
#  <div id="l114" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s114">
#   <div class="contentmargin0" style="color:#666666;">
#    Cachoeira, Brazil
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Brazil</td>-->
#  <div id="d114">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10574801');">
#   <b>
#    Hearts and Hands
#   </b>
#  </a>
#  <br/>
#  <div id="l10574801" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10574801">
#   <div class="contentmargin0" style="color:#666666;">
#    Georgetown, Guyana
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Guyana</td>-->
#  <div id="d10574801">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10583303');">
#   <b>
#    Instituto Ambiental Pericuma
#   </b>
#  </a>
#  <br/>
#  <div id="l10583303" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10583303">
#   <div class="contentmargin0" style="color:#666666;">
#    PINHEIRO, Brazil
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Brazil</td>-->
#  <div id="d10583303">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10571195');">
#   <b>
#    Instituto de Investigacion y Promocion Social para el Desarrollo
#   </b>
#  </a>
#  <br/>
#  <div id="l10571195" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10571195">
#   <div class="contentmargin0" style="color:#666666;">
#    Lima, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10571195">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10578879');">
#   <b>
#    Kolping  Foundation  Paraguay
#   </b>
#  </a>
#  <br/>
#  <div id="l10578879" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10578879">
#   <div class="contentmargin0" style="color:#666666;">
#    Fdo de la Mora, Paraguay
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Paraguay</td>-->
#  <div id="d10578879">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10578881');">
#   <b>
#    Kolping Foundation Paraguay
#   </b>
#  </a>
#  <br/>
#  <div id="l10578881" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10578881">
#   <div class="contentmargin0" style="color:#666666;">
#    Fdo de la Mora, Paraguay
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Paraguay</td>-->
#  <div id="d10578881">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10568270');">
#   <b>
#    Latin American Permaculture Institute
#   </b>
#  </a>
#  <br/>
#  <div id="l10568270" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10568270">
#   <div class="contentmargin0" style="color:#666666;">
#    Cochabamba, Bolivia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Bolivia</td>-->
#  <div id="d10568270">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10579379');">
#   <b>
#    Latitud Sur
#   </b>
#  </a>
#  <br/>
#  <div id="l10579379" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10579379">
#   <div class="contentmargin0" style="color:#666666;">
#    IQUITOS, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10579379">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10583143');">
#   <b>
#    Maestros sin Fronteras Peru
#   </b>
#  </a>
#  <br/>
#  <div id="l10583143" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10583143">
#   <div class="contentmargin0" style="color:#666666;">
#    San Sebastian, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10583143">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10580495');">
#   <b>
#    Maestros sin Fronteras Peru
#   </b>
#  </a>
#  <br/>
#  <div id="l10580495" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10580495">
#   <div class="contentmargin0" style="color:#666666;">
#    Cusco, Peru
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Peru</td>-->
#  <div id="d10580495">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10577193');">
#   <b>
#    Merundoi Inc
#   </b>
#  </a>
#  <br/>
#  <div id="l10577193" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10577193">
#   <div class="contentmargin0" style="color:#666666;">
#    Prashad Nagar, Guyana
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Guyana</td>-->
#  <div id="d10577193">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10590701');">
#   <b>
#    MisiÃ³n Verde Amazonia
#   </b>
#  </a>
#  <br/>
#  <div id="l10590701" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10590701">
#   <div class="contentmargin0" style="color:#666666;">
#    Florencia, Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10590701">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10578878');">
#   <b>
#    OIPIC
#   </b>
#  </a>
#  <br/>
#  <div id="l10578878" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10578878">
#   <div class="contentmargin0" style="color:#666666;">
#    ASUNCION, Paraguay
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Paraguay</td>-->
#  <div id="d10578878">
#  </div>
#  <br/>
#  <a href="javascript:loadOrg('10592599');">
#   <b>
#    Ong Funsocial Grow Colombia
#   </b>
#  </a>
#  <br/>
#  <div id="l10592599" style="display:none;">
#   <img src="images/resources/loading.gif"/>
#  </div>
#  <div id="s10592599">
#   <div class="contentmargin0" style="color:#666666;">
#    Bogota D.C., Colombia
#   </div>
#   <div class="contentmargin0">
#   </div>
#  </div>
#  <!--<td valign="top">Colombia</td>-->
#  <div id="d10592599">
#  </div>
#  <br/>
#  <div align="left">
#   Page:
#   <b>
#    1
#   </b>
#   <a href="javascript:goPage('2',  '', 'zz');void(0);">
#    2
#   </a>
#   <a href="javascript:goPage('2',  '', 'zz');void(0);">
#    &gt;
#   </a>
#   <a href="javascript:goPage('2',  '', 'zz');void(0);">
#    &gt;&gt;
#   </a>
#  </div>
#  <img height="1" src="images/0.gif" width="200"/>
#  <a href="javascript:goPage('2' , '', 'zz');void(0);">
#   <b>
#    Next 50 &gt;&gt;
#   </b>
#  </a>
# </td>

# %%
for link in main_content.findAll(relevant_links):
    ngo_id = int(float(re.search("javascript:loadOrg((.+?));",
                                 link['href']).group(1)[2:-2]))
# Out:
# 824
# 10586209
# 10580947
# 17172
# 10583244
# 10582006
# 10593128
# 383
# 10590124
# 10582318
# 10522771
# 126
# 10589454
# 10585352
# 17187
# 10590777
# 10574290
# 10577611
# 10574796
# 10591232
# 10664
# 10576022
# 10574420
# 10581593
# 10582247
# 10574400
# 993
# 10585363
# 10589885
# 10579388
# 10576589
# 10581130
# 10581235
# 10584367
# 10579375
# 10588285
# 114
# 10574801
# 10583303
# 10571195
# 10578879
# 10578881
# 10568270
# 10579379
# 10583143
# 10580495
# 10577193
# 10590701
# 10578878
# 10592599
